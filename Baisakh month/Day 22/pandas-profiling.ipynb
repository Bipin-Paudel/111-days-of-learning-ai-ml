# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# !pip install pandas-profiling
# Out:
# Collecting pandas-profiling
#   Downloading pandas_profiling-3.6.6-py2.py3-none-any.whl.metadata (4.5 kB)
# Collecting ydata-profiling (from pandas-profiling)
#   Downloading ydata_profiling-4.18.4-py2.py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: scipy<1.17,>=1.8 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from ydata-profiling->pandas-profiling) (1.15.3)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.5 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from ydata-profiling->pandas-profiling) (2.3.3)
# Collecting matplotlib<=3.10,>=3.5 (from ydata-profiling->pandas-profiling)
#   Downloading matplotlib-3.10.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (11 kB)
# Collecting pydantic<3,>=2 (from ydata-profiling->pandas-profiling)
#   Using cached pydantic-2.13.3-py3-none-any.whl.metadata (108 kB)
# Requirement already satisfied: PyYAML<6.1,>=6.0.3 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from ydata-profiling->pandas-profiling) (6.0.3)
# Requirement already satisfied: jinja2<3.2,>=3.1.6 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from ydata-profiling->pandas-profiling) (3.1.6)
# Collecting visions<0.8.2,>=0.7.5 (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling->pandas-profiling)
#   Downloading visions-0.8.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.4,>=1.22 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from ydata-profiling->pandas-profiling) (2.2.6)
# Collecting minify-html>=0.15.0 (from ydata-profiling->pandas-profiling)
#   Downloading minify_html-0.18.1-cp310-cp310-macosx_11_0_arm64.whl.metadata (18 kB)
# Collecting filetype>=1.0.0 (from ydata-profiling->pandas-profiling)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting phik<0.13,>=0.12.5 (from ydata-profiling->pandas-profiling)
#   Downloading phik-0.12.5-cp310-cp310-macosx_11_0_arm64.whl.metadata (5.6 kB)
# Requirement already satisfied: requests<3,>=2.32.0 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from ydata-profiling->pandas-profiling) (2.33.1)
# Collecting tqdm<5,>=4.66.3 (from ydata-profiling->pandas-profiling)
#   Using cached tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from ydata-profiling->pandas-profiling) (0.13.2)
# Collecting multimethod<2,>=1.4 (from ydata-profiling->pandas-profiling)
#   Downloading multimethod-1.12-py3-none-any.whl.metadata (9.6 kB)
# Collecting statsmodels<1,>=0.13.2 (from ydata-profiling->pandas-profiling)
#   Downloading statsmodels-0.14.6-cp310-cp310-macosx_11_0_arm64.whl.metadata (9.5 kB)
# Collecting typeguard<5,>=4 (from ydata-profiling->pandas-profiling)
#   Downloading typeguard-4.5.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting imagehash==4.3.2 (from ydata-profiling->pandas-profiling)
#   Downloading ImageHash-4.3.2-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting wordcloud>=1.9.4 (from ydata-profiling->pandas-profiling)
#   Downloading wordcloud-1.9.6-cp310-cp310-macosx_11_0_arm64.whl.metadata (3.4 kB)
# Collecting dacite<2,>=1.9 (from ydata-profiling->pandas-profiling)
#   Downloading dacite-1.9.2-py3-none-any.whl.metadata (17 kB)
# Collecting numba<0.63,>=0.60 (from ydata-profiling->pandas-profiling)
#   Downloading numba-0.62.1-cp310-cp310-macosx_11_0_arm64.whl.metadata (2.8 kB)
# Collecting PyWavelets (from imagehash==4.3.2->ydata-profiling->pandas-profiling)
#   Downloading pywavelets-1.8.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (9.0 kB)
# Requirement already satisfied: pillow in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from imagehash==4.3.2->ydata-profiling->pandas-profiling) (12.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from jinja2<3.2,>=3.1.6->ydata-profiling->pandas-profiling) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling->pandas-profiling) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling->pandas-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling->pandas-profiling) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling->pandas-profiling) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling->pandas-profiling) (26.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling->pandas-profiling) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling->pandas-profiling) (2.9.0.post0)
# Collecting llvmlite<0.46,>=0.45.0dev0 (from numba<0.63,>=0.60->ydata-profiling->pandas-profiling)
#   Downloading llvmlite-0.45.1-cp310-cp310-macosx_11_0_arm64.whl.metadata (4.8 kB)
# Requirement already satisfied: pytz>=2020.1 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling->pandas-profiling) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling->pandas-profiling) (2026.2)
# Collecting joblib>=0.14.1 (from phik<0.13,>=0.12.5->ydata-profiling->pandas-profiling)
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=2->ydata-profiling->pandas-profiling)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.46.3 (from pydantic<3,>=2->ydata-profiling->pandas-profiling)
#   Downloading pydantic_core-2.46.3-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Requirement already satisfied: typing-extensions>=4.14.1 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from pydantic<3,>=2->ydata-profiling->pandas-profiling) (4.15.0)
# Collecting typing-inspection>=0.4.2 (from pydantic<3,>=2->ydata-profiling->pandas-profiling)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from requests<3,>=2.32.0->ydata-profiling->pandas-profiling) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from requests<3,>=2.32.0->ydata-profiling->pandas-profiling) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from requests<3,>=2.32.0->ydata-profiling->pandas-profiling) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from requests<3,>=2.32.0->ydata-profiling->pandas-profiling) (2026.4.22)
# Collecting patsy>=0.5.6 (from statsmodels<1,>=0.13.2->ydata-profiling->pandas-profiling)
#   Downloading patsy-1.0.2-py2.py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: attrs>=19.3.0 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling->pandas-profiling) (26.1.0)
# Collecting networkx>=2.4 (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling->pandas-profiling)
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting puremagic (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling->pandas-profiling)
#   Downloading puremagic-1.30-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: six>=1.5 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling->pandas-profiling) (1.17.0)
# Downloading pandas_profiling-3.6.6-py2.py3-none-any.whl (324 kB)
# Downloading ydata_profiling-4.18.4-py2.py3-none-any.whl (400 kB)
# Downloading ImageHash-4.3.2-py2.py3-none-any.whl (296 kB)
# Downloading dacite-1.9.2-py3-none-any.whl (16 kB)
# Downloading matplotlib-3.10.0-cp310-cp310-macosx_11_0_arm64.whl (8.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 2.8 MB/s  0:00:02m 2.8 MB/s eta 0:00:01
# Downloading multimethod-1.12-py3-none-any.whl (10 kB)
# Downloading numba-0.62.1-cp310-cp310-macosx_11_0_arm64.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 3.9 MB/s  0:00:004.1 MB/s eta 0:00:01:01
# Downloading llvmlite-0.45.1-cp310-cp310-macosx_11_0_arm64.whl (37.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 4.4 MB/s  0:00:08a 0:00:01m eta 0:00:01
# Downloading phik-0.12.5-cp310-cp310-macosx_11_0_arm64.whl (664 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.3/664.3 kB 7.6 MB/s  0:00:00
# Using cached pydantic-2.13.3-py3-none-any.whl (471 kB)
# Downloading pydantic_core-2.46.3-cp310-cp310-macosx_11_0_arm64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 7.4 MB/s  0:00:007.7 MB/s eta 0:00:01
# Downloading statsmodels-0.14.6-cp310-cp310-macosx_11_0_arm64.whl (10.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 7.5 MB/s  0:00:01 7.5 MB/s eta 0:00:01
# Using cached tqdm-4.67.3-py3-none-any.whl (78 kB)
# Downloading typeguard-4.5.1-py3-none-any.whl (36 kB)
# Downloading visions-0.8.1-py3-none-any.whl (105 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading minify_html-0.18.1-cp310-cp310-macosx_11_0_arm64.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 4.6 MB/s  0:00:00m 8.8 MB/s eta 0:00:01
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 4.4 MB/s  0:00:00m 4.4 MB/s eta 0:00:01
# Downloading patsy-1.0.2-py2.py3-none-any.whl (233 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading wordcloud-1.9.6-cp310-cp310-macosx_11_0_arm64.whl (168 kB)
# Downloading puremagic-1.30-py3-none-any.whl (43 kB)
# Downloading pywavelets-1.8.0-cp310-cp310-macosx_11_0_arm64.whl (4.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 7.8 MB/s  0:00:007.8 MB/s eta 0:00:01:01
# Installing collected packages: puremagic, minify-html, filetype, typing-inspection, typeguard, tqdm, PyWavelets, pydantic-core, patsy, networkx, multimethod, llvmlite, joblib, dacite, annotated-types, pydantic, numba, matplotlib, imagehash, wordcloud, visions, statsmodels, phik, ydata-profiling, pandas-profiling
#   Attempting uninstall: matplotlib━━━━━━━━━━━━╸━━━━━━━━━━━━━━ 16/25 [numba]te]
#     Found existing installation: matplotlib 3.10.9;2;249;38;114m╸━━━━━━━━━━━━━━ 16/25 [numba]
#     Uninstalling matplotlib-3.10.9:━━━━━━━╸━━━━━━━━━━━━━━ 16/25 [numba]
#       Successfully uninstalled matplotlib-3.10.9╺━━━━━━━━━━━━ 17/25 [matplotlib]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25/25 [pandas-profiling] 23/25 [ydata-profiling]
# Successfully installed PyWavelets-1.8.0 annotated-types-0.7.0 dacite-1.9.2 filetype-1.2.0 imagehash-4.3.2 joblib-1.5.3 llvmlite-0.45.1 matplotlib-3.10.0 minify-html-0.18.1 multimethod-1.12 networkx-3.4.2 numba-0.62.1 pandas-profiling-3.6.6 patsy-1.0.2 phik-0.12.5 puremagic-1.30 pydantic-2.13.3 pydantic-core-2.46.3 statsmodels-0.14.6 tqdm-4.67.3 typeguard-4.5.1 typing-inspection-0.4.2 visions-0.8.1 wordcloud-1.9.6 ydata-profiling-4.18.4

# %%
# !pip install ydata-profiling
# Out:
# Requirement already satisfied: ydata-profiling in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (4.18.4)
# Requirement already satisfied: scipy<1.17,>=1.8 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from ydata-profiling) (1.15.3)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.5 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from ydata-profiling) (2.3.3)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from ydata-profiling) (3.10.0)
# Requirement already satisfied: pydantic<3,>=2 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from ydata-profiling) (2.13.3)
# Requirement already satisfied: PyYAML<6.1,>=6.0.3 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from ydata-profiling) (6.0.3)
# Requirement already satisfied: jinja2<3.2,>=3.1.6 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from ydata-profiling) (3.1.6)
# Requirement already satisfied: visions<0.8.2,>=0.7.5 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (0.8.1)
# Requirement already satisfied: numpy<2.4,>=1.22 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from ydata-profiling) (2.2.6)
# Requirement already satisfied: minify-html>=0.15.0 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from ydata-profiling) (0.18.1)
# Requirement already satisfied: filetype>=1.0.0 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from ydata-profiling) (1.2.0)
# Requirement already satisfied: phik<0.13,>=0.12.5 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from ydata-profiling) (0.12.5)
# Requirement already satisfied: requests<3,>=2.32.0 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from ydata-profiling) (2.33.1)
# Requirement already satisfied: tqdm<5,>=4.66.3 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from ydata-profiling) (4.67.3)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from ydata-profiling) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from ydata-profiling) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from ydata-profiling) (0.14.6)
# Requirement already satisfied: typeguard<5,>=4 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from ydata-profiling) (4.5.1)
# Requirement already satisfied: imagehash==4.3.2 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from ydata-profiling) (4.3.2)
# Requirement already satisfied: wordcloud>=1.9.4 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from ydata-profiling) (1.9.6)
# Requirement already satisfied: dacite<2,>=1.9 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from ydata-profiling) (1.9.2)
# Requirement already satisfied: numba<0.63,>=0.60 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from ydata-profiling) (0.62.1)
# Requirement already satisfied: PyWavelets in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from imagehash==4.3.2->ydata-profiling) (1.8.0)
# Requirement already satisfied: pillow in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from imagehash==4.3.2->ydata-profiling) (12.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from jinja2<3.2,>=3.1.6->ydata-profiling) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (26.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from numba<0.63,>=0.60->ydata-profiling) (0.45.1)
# Requirement already satisfied: pytz>=2020.1 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2026.2)
# Requirement already satisfied: joblib>=0.14.1 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from phik<0.13,>=0.12.5->ydata-profiling) (1.5.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from pydantic<3,>=2->ydata-profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from pydantic<3,>=2->ydata-profiling) (2.46.3)
# Requirement already satisfied: typing-extensions>=4.14.1 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from pydantic<3,>=2->ydata-profiling) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from pydantic<3,>=2->ydata-profiling) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from requests<3,>=2.32.0->ydata-profiling) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from requests<3,>=2.32.0->ydata-profiling) (2026.4.22)
# Requirement already satisfied: patsy>=0.5.6 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (1.0.2)
# Requirement already satisfied: attrs>=19.3.0 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (26.1.0)
# Requirement already satisfied: networkx>=2.4 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (3.4.2)
# Requirement already satisfied: puremagic in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (1.30)
# Requirement already satisfied: six>=1.5 in /Users/bipinpaudel/miniconda3/envs/base_env/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling) (1.17.0)

# %%
from ydata_profiling import ProfileReport
prof = ProfileReport(df)
prof.to_file(output_file='output.html')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from ydata_profiling import ProfileReport
#       2 prof = ProfileReport(df)
#       3 prof.to_file(output_file='output.html')
#
# File ~/miniconda3/envs/base_env/lib/python3.10/site-packages/ydata_profiling/__init__.py:11
#       8 import importlib.util  # isort:skip # noqa
#       9 from warnings import warn
# ---> 11 from ydata_profiling.compare_reports import compare  # isort:skip # noqa
#      12 from ydata_profiling.controller import pandas_decorator  # isort:skip # noqa
#      13 from ydata_profiling.profile_report import ProfileReport  # isort:skip # noqa
#
# File ~/miniconda3/envs/base_env/lib/python3.10/site-packages/ydata_profiling/compare_reports.py:12
#      10 from ydata_profiling.model import BaseDescription
#      11 from ydata_profiling.model.alerts import Alert
# ---> 12 from ydata_profiling.profile_report import ProfileReport
#      15 def _should_wrap(v1: Any, v2: Any) -> bool:
#      16     if isinstance(v1, (list, dict)):
#
# File ~/miniconda3/envs/base_env/lib/python3.10/site-packages/ydata_profiling/profile_report.py:11
#       9 with warnings.catch_warnings():
#      10     warnings.simplefilter("ignore")
# ---> 11     import pkg_resources
#      13 if not is_pyspark_installed():
#      14     from typing import TypeVar
#
# ModuleNotFoundError: No module named 'pkg_resources'
